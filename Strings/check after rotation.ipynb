# %% [markdown]
# <a href="https://colab.research.google.com/github/Isha-Sisodia/DSA-Practice/blob/main/Strings/check%20after%20rotation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Question -**
# Check if Strings Are Rotations of Each Other
# Last Updated : 3 Oct, 2025
# Given two strings s1 and s2 of equal length, determine whether s2 is a rotation of s1.
# A string is said to be a rotation of another if it can be obtained by shifting some leading characters of the original string to its end without changing the order of characters.
# **Examples: **
#
# Input: s1 = "abcd", s2 = "cdab"
# Output: true
# Explanation: After 2 right rotations, s1 will become equal to s2.
#
# Input: s1 = "aab", s2 = "aba"
# Output: true
# Explanation: After 1 left rotation, s1 will become equal to s2.
#
# Input: s1 = "abcd", s2 = "acbd"
# Output: false
# Explanation: Strings are not rotations of each other.

# %% [markdown]
# **Key Observation (VERY IMPORTANT)**
#
# If s2 is a rotation of s1, then:
#
# s2 must be a substring of s1 + s1
#
# **✅ Algorithm**
#
# 1. If lengths are different → return false
# 2. Concatenate s1 with itself → temp = s1 + s1
# 3. Check if s2 is a substring of temp
# 4. If yes → true, else → false

# %%
https://www.geeksforgeeks.org/problems/check-if-strings-are-rotations-of-each-other-or-not-1587115620/1

class Solution:
    def areRotations(self, s1, s2):
        # code here
        if len(s1) != len(s2):
            return False
        elif s2 in (s1+s1):
            return True
        else:
            return False

# %%
# Using Concatnation
def if_rotate(s1,s2):
  if len(s1) != len(s2):
    return False
  elif s2 in (s1+s1):
    return True
  else:
    return False
print(if_rotate("abcd","cdab"))    #True
print(if_rotate("aab","aba"))      #True
print(if_rotate("abcd","acbd"))    #False
# Out:
# True
# True
# False

# %%
# Using Slicing
# while submitting this approach..it gives TLE(time limit exceeding)
def Rotate(s1,s2):
  if len(s1) != len(s2):
    return False
  else:
    for i in range(len(s1)):
      s1 = s1[1:] +s1[0]
      if s1 == s2:
        return True
    return False
Rotate("abcd","cdab")    #True
Rotate("aab","aba")      #True
Rotate("abcd","acbd")    #False
# Out:
# False
