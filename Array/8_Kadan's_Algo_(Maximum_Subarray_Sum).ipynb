# %% [markdown]
# <a href="https://colab.research.google.com/github/Isha-Sisodia/DSA-Practice/blob/main/Array/8_Kadan's_Algo_(Maximum_Subarray_Sum).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Link - https://leetcode.com/problems/maximum-subarray/submissions/1965037749/

# %%
# TLE error so i cant submit
nums = [1,2,3,4,5]
def maxSubArray(nums):
  max_sum = nums[0]
  for i in range(len(nums)):
    curr_sum = 0
    for j in range(i,len(nums)):
      curr_sum += nums[j]
      max_sum = max(max_sum, curr_sum)
  return max_sum
maxSubArray(nums)
# Out:
# 15

# %%
# TLE
class Solution:
    def maxSubArray(self, nums: List[int]) -> int:
        max_sum = nums[0]
        for i in range(len(nums)):
            curr_sum = 0
            for j in range(i,len(nums)):
                curr_sum += nums[j]
                max_sum = max(max_sum, curr_sum)
        return max_sum

# %%
# Optimised - Kadanes Algorithm
num = [1,2,6,4,5]
def kadanesAlgo(num):
  max_sum = num[0]
  curr_sum = num[0]
  for i in range(1, len(num)):
    curr_sum = max(num[i], curr_sum + num[i])
    max_sum = max(max_sum, curr_sum)
  return max_sum
kadanesAlgo(num)
# Out:
# 18

# %%
# Final submit code
class Solution(object):
    def maxSubArray(self, nums):
        max_sum = nums[0]
        curr_sum = nums[0]
        for i in range(1,len(nums)):
            curr_sum = max(nums[i], curr_sum+nums[i])
            max_sum = max(curr_sum , max_sum)
        return max_sum
